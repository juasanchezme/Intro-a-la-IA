# %% [markdown]
# # Lógica difusa

# %% [markdown]
# ## 🔍 ¿Qué es la lógica difusa?
#
# La lógica difusa (fuzzy logic, en inglés) es una extensión de la lógica clásica (verdadero o falso, 1 o 0) que permite trabajar con valores intermedios, es decir, grados de verdad entre 0 y 1. Es especialmente útil para modelar situaciones en las que la información no es precisa o es cualitativa, como: “hace calor”, “la velocidad es alta”, “el tanque está casi lleno”, etc.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 🧠 ¿Qué es la defuzzificación?
#
# Después de aplicar las reglas difusas, obtenemos una salida difusa: una función de pertenencia que nos dice con qué grado se cumple cada posible salida. Pero los sistemas físicos (un motor, una válvula, un ventilador, etc.) necesitan un valor específico.
#
# ➡️ La defuzzificación es el proceso de traducir esa salida difusa en un único valor numérico real **(crisp).**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
